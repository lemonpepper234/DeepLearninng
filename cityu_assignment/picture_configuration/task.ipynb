# %%
import numpy as np
import h5py
from PIL import Image
import matplotlib.pyplot as plt
from tools import *

num_px = 64
num_py = 64
filename = "images/gao.jpg"
activation = "relu"

predict_picture(filename, num_px, num_py, activation)
# Out:
# y = 1, you predicted that it is a "cat" picture.
